# %% [markdown]
# # 1.3.1 Basic Operations on Images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('cat2.jpg')
px = img[100,100]
print(px)
# Out:
# [187 198 206]

# %%
def pltImage(img):
    plt.imshow(img)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
pltImage(img)

# %%
# accessing only blue pixel
blue = img[100,100,0]
print(blue)
# Out:
# 187

# %%
img[100,100] = [0,0,0]
pltImage(img)

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
img.size
# Out:
# 921600

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
w = 100
ball = img[280:(280+w), 330:(330+w)]

# %%
pltImage(ball)

# %%
img[10:10+w, 10:10+w] = ball
pltImage(img)

# %%
b,g,r = cv2.split(img)

# %%
b.shape
# Out:
# (480, 640)

# %%
r
# Out:
# array([[  2,   8,   9, ..., 182, 191, 160],
#        [  5,  10,   9, ..., 152, 156, 177],
#        [  8,  12,  10, ..., 162, 179, 195],
#        ...,
#        [235, 229, 199, ..., 204, 186, 148],
#        [226, 220, 177, ..., 218, 206, 173],
#        [245, 242, 202, ..., 201, 210, 212]], dtype=uint8)

# %%
img = cv2.merge((r,g,b))

# %%
pltImage(img)

# %%
pltImage(r)

# %%
pltImage(g)

# %%
pltImage(b)

# %%
BLUE = [255,0,0]
img1 = cv2.imread('cat2.jpg')
m = 100
replicate = cv2.copyMakeBorder(img1,m,m,m,m,cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img1,m,m,m,m,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img1,m,m,m,m,cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img1,m,m,m,m,cv2.BORDER_WRAP)
constant= cv2.copyMakeBorder(img1,m,m,m,m,cv2.BORDER_CONSTANT,value=BLUE)

# %%
plt.rcParams["figure.figsize"] = (20,10)
plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')
plt.show()
